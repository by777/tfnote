# %% [markdown]
# > 用Sequential搭建神经网络，可以搭建出上层网络输出就是下层输入的顺序网络结构，但是无法写出带有跳连的非顺序网络结构。这时需要使用class搭建神经网络结构。

# %% [markdown]
# # 六步法
#
# + import
# + train, test
# + class MyModel(Model) model = MyModel
# + model.compile()
# + model.fit()
# + model.summary()
# ------------------

# %% [markdown]
# ## class MyModel:
#
#     class MyModel(Model):
#         def __init__(self):
#           super(MyModel,self).__init__()
#           定义网络结构
#         def call(self,x):
#            调用网络结构块，实现前向传播
#            return y
#      model = MyModel()
#
# ----------------
# 如：
#
#     class IrisModel(Model):
#         def __init__(self):
#             super(IrisModel,self).__init__()
#             self.d1 = Dense(3)
#             # d1是给这一层起的名字
#         def call(self,x):
#             y = self.d1(x)
#             return y
#
#      model = IrisModel()

# %%
import tensorflow as tf
from sklearn import datasets
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import SparseCategoricalCrossentropy

x_train = datasets.load_iris().data
y_train = datasets.load_iris().target

np.random.seed(116)
np.random.shuffle(x_train)
np.random.seed(116)
np.random.shuffle(y_train)
np.random.seed(116)

class IrisModel(Model):
    def __init__(self):
        super(IrisModel,self).__init__()
        self.d1 = Dense(3,activation='softmax',kernel_regularizer=l2())
    def call(self,x):
        y = self.d1(x)
        return y

model = IrisModel()
model.compile(optimizer=SGD(lr=0.1),loss=SparseCategoricalCrossentropy(from_logits=False),
              metrics = ['sparse_categorical_accuracy'])
model.fit(x_train,y_train,batch_size=32,epochs=500,validation_split=0.2,validation_freq=20)
model.summary()
# Out:
# Train on 120 samples, validate on 30 samples
# Epoch 1/500
# 120/120 [==============================] - 0s 2ms/sample - loss: 1.3809 - sparse_categorical_accuracy: 0.6000
# Epoch 2/500
# 120/120 [==============================] - 0s 66us/sample - loss: 0.9436 - sparse_categorical_accuracy: 0.6333
# Epoch 3/500
# 120/120 [==============================] - 0s 50us/sample - loss: 0.6658 - sparse_categorical_accuracy: 0.7000
# Epoch 4/500
# 120/120 [==============================] - 0s 58us/sample - loss: 0.5573 - sparse_categorical_accuracy: 0.7583
# Epoch 5/500
# 120/120 [==============================] - 0s 58us/sample - loss: 0.5527 - sparse_categorical_accuracy: 0.7750
# Epoch 6/500
# 120/120 [==============================] - 0s 67us/sample - loss: 0.7798 - sparse_categorical_accuracy: 0.6417
# Epoch 7/500
# 120/120 [==============================] - 0s 59us/sample - loss: 0.5966 - sparse_categorical_accuracy: 0.7250
# Epoch 8/500
# ...
