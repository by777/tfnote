# %%
import tensorflow as tf
from sklearn import datasets
from matplotlib import pyplot as plt
import numpy as np
import time  

x_data = datasets.load_iris().data
y_data = datasets.load_iris().target

np.random.seed(116)  
np.random.shuffle(x_data)
np.random.seed(116)
np.random.shuffle(y_data)
tf.random.set_seed(116)

# 将打乱后的数据集分割为训练集和测试集，训练集为前120行，测试集为后30行
x_train = x_data[:-30]
y_train = y_data[:-30]
x_test = x_data[-30:]
y_test = y_data[-30:]

# 转换x的数据类型，否则后面矩阵相乘时会因数据类型不一致报错
x_train = tf.cast(x_train, tf.float32)
x_test = tf.cast(x_test, tf.float32)


train_db = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(32)
test_db = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(32)


w1 = tf.Variable(tf.random.truncated_normal([4, 3], stddev=0.1, seed=1))
b1 = tf.Variable(tf.random.truncated_normal([3], stddev=0.1, seed=1))

lr = 0.1  # 学习率为0.1
train_loss_results = []  # 将每轮的loss记录在此列表中，为后续画loss曲线提供数据
test_acc = []  # 将每轮的acc记录在此列表中，为后续画acc曲线提供数据
epoch = 500  # 循环500轮
loss_all = 0  # 每轮分4个step，loss_all记录四个step生成的4个loss的和

##########################################################################
m_w, m_b = 0, 0
v_w, v_b = 0, 0
beta1, beta2 = 0.9, 0.999
delta_w, delta_b = 0, 0
global_step = 0
##########################################################################

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
now_time = time.time()
for epoch in range(epoch):
    for step,(x_train,y_train) in enumerate(train_db):
        ####
        global_step += 1
        ####
        with tf.GradientTape() as tape:
            y = tf.matmul(x_train,w1) + b1
            y = tf.nn.softmax(y)
            y_ = tf.one_hot(y_train,depth=3)
            loss = tf.reduce_mean(tf.square(y_ -y))
            loss_all += loss.numpy()
        grads = tape.gradient(loss,[w1,b1])
        
        ######adam#####
        m_w = beta1 * m_w + (1 - beta1) * grads[0]
        m_b = beta1 * m_b + (1 - beta1) * grads[1]
        v_w = beta2 * v_w + (1 - beta2) * tf.square(grads[0])
        v_b = beta2 * v_b + (1 - beta2) * tf.square(grads[1])
        
        m_w_correction = m_w / (1 - tf.pow(beta1,int(global_step)))
        m_b_correction = m_b / (1 - tf.pow(beta1,int(global_step)))
        v_w_correction = v_w / (1 - tf.pow(beta2,int(global_step)))
        v_b_correction = v_b / (1 - tf.pow(beta2,int(global_step)))
        
        w1.assign_sub(lr * m_w_correction / tf.sqrt(v_w_correction))
        b1.assign_sub(lr * m_b_correction / tf.sqrt(v_b_correction))
    print("Epoch:{},loss{}".format(epoch,loss_all/4))
    train_loss_results.append(loss_all / 4)
    loss_all = 0
    
    print("测试部分")
    total_correct,total_number = 0,0
    for x_test,y_test in test_db:
        y = tf.matmul(x_test,w1) + b1
        y = tf.nn.softmax(y)
        pred = tf.argmax(y,axis=1)
        pred = tf.cast(pred,y_test.dtype)
        correct = tf.cast(tf.equal(pred,y_test),dtype=tf.int32)
        correct = tf.reduce_sum(correct)
        total_correct += int(correct)
         # total_number为测试的总样本数，也就是x_test的行数，shape[0]返回变量的行数
        total_number += x_test.shape[0]
    acc = total_correct / total_number
    test_acc.append(acc)
    print("test acc:",acc)
    print("---------")
total_time = time.time() - now_time
print("total_time:",total_time)

# 绘制loss曲线
plt.title("Loss Function Curve")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.plot(train_loss_results,label="$Loss$")
# 逐点画出trian_loss_results值并连线，连线图标是Loss
plt.legend() #画出曲线图标
plt.show()

# 绘制acc曲线
plt.title("Acc Curve")
plt.xlabel("Epoch")
plt.ylabel("Acc")
plt.plot(test_acc,label="$Accuracy$")
#逐点画出test_acc值并连线，连线图标是Accuracy
plt.legend()
plt.show()
# Out:
# Epoch:0,loss0.21984169632196426
# 测试部分
# test acc: 0.5333333333333333
# ---------
# Epoch:1,loss0.14480622671544552
# 测试部分
# test acc: 0.5333333333333333
# ---------
# Epoch:2,loss0.10274342261254787
# 测试部分
# test acc: 0.6666666666666666
# ---------
# Epoch:3,loss0.08922167308628559
# 测试部分
# test acc: 0.5333333333333333
# ---------
# Epoch:4,loss0.08600791450589895
# 测试部分
# test acc: 0.9
# ---------
# Epoch:5,loss0.06994976289570332
# 测试部分
# test acc: 0.8
# ---------
# Epoch:6,loss0.06724478956311941
# 测试部分
# test acc: 0.8
# ---------
# Epoch:7,loss0.06104544270783663
# 测试部分
# test acc: 1.0
# ---------
# Epoch:8,loss0.055738057009875774
# 测试部分
# test acc: 0.9333333333333333
# ---------
# Epoch:9,loss0.05405292101204395
# 测试部分
# test acc: 1.0
# ---------
# Epoch:10,loss0.04909192584455013
# 测试部分
# test acc: 1.0
# ---------
# Epoch:11,loss0.04825872555375099
# 测试部分
# test acc: 1.0
# ---------
# Epoch:12,loss0.044586071744561195
# 测试部分
# test acc: 1.0
# ---------
# Epoch:13,loss0.04371032351627946
# 测试部分
# test acc: 1.0
# ---------
# Epoch:14,loss0.04151798691600561
# 测试部分
# test acc: 1.0
# ---------
# Epoch:15,loss0.04042437160387635
# 测试部分
# test acc: 1.0
# ---------
# Epoch:16,loss0.039219165686517954
# 测试部分
# test acc: 1.0
# ---------
# Epoch:17,loss0.03770230943337083
# 测试部分
# test acc: 1.0
# ---------
# Epoch:18,loss0.037467426154762506
# 测试部分
# test acc: 1.0
# ---------
# Epoch:19,loss0.03545612841844559
# 测试部分
# test acc: 1.0
# ---------
# Epoch:20,loss0.03618234908208251
# 测试部分
# test acc: 1.0
# ---------
# Epoch:21,loss0.03353227535262704
# 测试部分
# test acc: 1.0
# ---------
# Epoch:22,loss0.03510434413328767
# 测试部分
# test acc: 1.0
# ---------
# Epoch:23,loss0.03179901000112295
# 测试部分
# test acc: 1.0
# ---------
# Epoch:24,loss0.03405483299866319
# 测试部分
# test acc: 1.0
# ---------
# Epoch:25,loss0.03026510076597333
# 测试部分
# test acc: 1.0
# ---------
# Epoch:26,loss0.03288380429148674
# 测试部分
# test acc: 1.0
# ---------
# Epoch:27,loss0.028981768060475588
# 测试部分
# test acc: 1.0
# ---------
# Epoch:28,loss0.03153964690864086
# 测试部分
# test acc: 1.0
# ---------
# Epoch:29,loss0.02803809940814972
# 测试部分
# test acc: 1.0
# ---------
# Epoch:30,loss0.030121163930743933
# 测试部分
# test acc: 1.0
# ---------
# Epoch:31,loss0.027460433542728424
# 测试部分
# test acc: 1.0
# ---------
# Epoch:32,loss0.0287771113216877
# 测试部分
# test acc: 1.0
# ---------
# Epoch:33,loss0.027132862713187933
# 测试部分
# test acc: 1.0
# ---------
# Epoch:34,loss0.027615335769951344
# 测试部分
# test acc: 1.0
# ---------
# Epoch:35,loss0.026862118393182755
# 测试部分
# test acc: 1.0
# ---------
# Epoch:36,loss0.02668721415102482
# 测试部分
# test acc: 1.0
# ---------
# Epoch:37,loss0.026502934750169516
# 测试部分
# test acc: 1.0
# ---------
# Epoch:38,loss0.025996240321546793
# 测试部分
# test acc: 1.0
# ---------
# Epoch:39,loss0.026023705024272203
# 测试部分
# test acc: 1.0
# ---------
# Epoch:40,loss0.025497347582131624
# 测试部分
# test acc: 1.0
# ---------
# Epoch:41,loss0.025481836404651403
# 测试部分
# test acc: 1.0
# ---------
# Epoch:42,loss0.02510706940665841
# 测试部分
# test acc: 1.0
# ---------
# Epoch:43,loss0.024957630783319473
# 测试部分
# test acc: 1.0
# ---------
# Epoch:44,loss0.02474378887563944
# 测试部分
# test acc: 1.0
# ---------
# Epoch:45,loss0.02450239099562168
# 测试部分
# test acc: 1.0
# ---------
# Epoch:46,loss0.024368164129555225
# 测试部分
# test acc: 1.0
# ---------
# Epoch:47,loss0.024121190886944532
# 测试部分
# test acc: 1.0
# ---------
# Epoch:48,loss0.023986989865079522
# 测试部分
# test acc: 1.0
# ---------
# Epoch:49,loss0.023787257494404912
# 测试部分
# test acc: 1.0
# ---------
# Epoch:50,loss0.02362554776482284
# 测试部分
# test acc: 1.0
# ---------
# Epoch:51,loss0.023471765918657184
# 测试部分
# test acc: 1.0
# ---------
# Epoch:52,loss0.023299254709854722
# 测试部分
# test acc: 1.0
# ---------
# Epoch:53,loss0.023163855308666825
# 测试部分
# test acc: 1.0
# ---------
# Epoch:54,loss0.023004947928711772
# 测试部分
# test acc: 1.0
# ---------
# Epoch:55,loss0.022868582978844643
# 测试部分
# test acc: 1.0
# ---------
# Epoch:56,loss0.02273069927468896
# 测试部分
# test acc: 1.0
# ---------
# Epoch:57,loss0.022593224188312888
# 测试部分
# test acc: 1.0
# ---------
# Epoch:58,loss0.022468635579571128
# 测试部分
# test acc: 1.0
# ---------
# Epoch:59,loss0.022338303504511714
# 测试部分
# test acc: 1.0
# ---------
# Epoch:60,loss0.02221843833103776
# 测试部分
# test acc: 1.0
# ---------
# Epoch:61,loss0.0220991347450763
# 测试部分
# test acc: 1.0
# ---------
# Epoch:62,loss0.02198242675513029
# 测试部分
# test acc: 1.0
# ---------
# Epoch:63,loss0.02187163825146854
# 测试部分
# test acc: 1.0
# ---------
# Epoch:64,loss0.02176067023538053
# 测试部分
# test acc: 1.0
# ---------
# Epoch:65,loss0.021654900163412094
# 测试部分
# test acc: 1.0
# ---------
# Epoch:66,loss0.021550956647843122
# 测试部分
# test acc: 1.0
# ---------
# Epoch:67,loss0.02144931606017053
# 测试部分
# test acc: 1.0
# ---------
# Epoch:68,loss0.021351238479837775
# 测试部分
# test acc: 1.0
# ---------
# Epoch:69,loss0.021254493622109294
# 测试部分
# test acc: 1.0
# ---------
# Epoch:70,loss0.02116078627295792
# 测试部分
# test acc: 1.0
# ---------
# Epoch:71,loss0.021069139475002885
# 测试部分
# test acc: 1.0
# ---------
# Epoch:72,loss0.020979418884962797
# 测试部分
# test acc: 1.0
# ---------
# Epoch:73,loss0.020892156986519694
# 测试部分
# test acc: 1.0
# ---------
# Epoch:74,loss0.020806539803743362
# 测试部分
# test acc: 1.0
# ---------
# Epoch:75,loss0.02072301576845348
# 测试部分
# test acc: 1.0
# ---------
# Epoch:76,loss0.02064135018736124
# 测试部分
# test acc: 1.0
# ---------
# Epoch:77,loss0.02056133165024221
# 测试部分
# test acc: 1.0
# ---------
# Epoch:78,loss0.02048318414017558
# 测试部分
# test acc: 1.0
# ---------
# Epoch:79,loss0.0204065868165344
# 测试部分
# test acc: 1.0
# ---------
# Epoch:80,loss0.02033161325380206
# 测试部分
# test acc: 1.0
# ---------
# Epoch:81,loss0.02025822177529335
# 测试部分
# test acc: 1.0
# ---------
# Epoch:82,loss0.020186253124848008
# 测试部分
# test acc: 1.0
# ---------
# Epoch:83,loss0.020115777850151062
# 测试部分
# test acc: 1.0
# ---------
# Epoch:84,loss0.02004667604342103
# 测试部分
# test acc: 1.0
# ---------
# Epoch:85,loss0.01997890556231141
# 测试部分
# test acc: 1.0
# ---------
# Epoch:86,loss0.0199124647770077
# 测试部分
# test acc: 1.0
# ---------
# Epoch:87,loss0.019847264979034662
# 测试部分
# test acc: 1.0
# ---------
# Epoch:88,loss0.01978328824043274
# 测试部分
# test acc: 1.0
# ---------
# Epoch:89,loss0.01972051989287138
# 测试部分
# test acc: 1.0
# ---------
# Epoch:90,loss0.01965886657126248
# 测试部分
# test acc: 1.0
# ---------
# Epoch:91,loss0.019598341081291437
# 测试部分
# test acc: 1.0
# ---------
# Epoch:92,loss0.019538887310773134
# 测试部分
# test acc: 1.0
# ---------
# Epoch:93,loss0.01948048430494964
# 测试部分
# test acc: 1.0
# ---------
# Epoch:94,loss0.019423091085627675
# 测试部分
# test acc: 1.0
# ---------
# Epoch:95,loss0.019366701133549213
# 测试部分
# test acc: 1.0
# ---------
# Epoch:96,loss0.01931125670671463
# 测试部分
# test acc: 1.0
# ---------
# Epoch:97,loss0.01925673265941441
# 测试部分
# test acc: 1.0
# ---------
# Epoch:98,loss0.019203137373551726
# 测试部分
# test acc: 1.0
# ---------
# Epoch:99,loss0.01915040146559477
# 测试部分
# test acc: 1.0
# ---------
# Epoch:100,loss0.019098521675914526
# 测试部分
# test acc: 1.0
# ---------
# Epoch:101,loss0.019047497073188424
# 测试部分
# test acc: 1.0
# ---------
# Epoch:102,loss0.018997250590473413
# 测试部分
# test acc: 1.0
# ---------
# Epoch:103,loss0.018947811797261238
# 测试部分
# test acc: 1.0
# ---------
# Epoch:104,loss0.018899145536124706
# 测试部分
# test acc: 1.0
# ---------
# Epoch:105,loss0.018851208966225386
# 测试部分
# test acc: 1.0
# ---------
# Epoch:106,loss0.018804015358909965
# 测试部分
# test acc: 1.0
# ---------
# Epoch:107,loss0.018757533514872193
# 测试部分
# test acc: 1.0
# ---------
# Epoch:108,loss0.018711725482717156
# 测试部分
# test acc: 1.0
# ---------
# Epoch:109,loss0.01866661780513823
# 测试部分
# test acc: 1.0
# ---------
# Epoch:110,loss0.018622154369950294
# 测试部分
# test acc: 1.0
# ---------
# Epoch:111,loss0.018578327959403396
# 测试部分
# test acc: 1.0
# ---------
# Epoch:112,loss0.01853515161201358
# 测试部分
# test acc: 1.0
# ---------
# Epoch:113,loss0.018492562463507056
# 测试部分
# test acc: 1.0
# ---------
# Epoch:114,loss0.01845057145692408
# 测试部分
# test acc: 1.0
# ---------
# Epoch:115,loss0.018409202340990305
# 测试部分
# test acc: 1.0
# ---------
# Epoch:116,loss0.0183683552313596
# 测试部分
# test acc: 1.0
# ---------
# Epoch:117,loss0.018328094854950905
# 测试部分
# test acc: 1.0
# ---------
# Epoch:118,loss0.018288368359208107
# 测试部分
# test acc: 1.0
# ---------
# Epoch:119,loss0.018249179236590862
# 测试部分
# test acc: 1.0
# ---------
# Epoch:120,loss0.018210510723292828
# 测试部分
# test acc: 1.0
# ---------
# Epoch:121,loss0.018172352109104395
# 测试部分
# test acc: 1.0
# ---------
# Epoch:122,loss0.018134684534743428
# 测试部分
# test acc: 1.0
# ---------
# Epoch:123,loss0.018097512423992157
# 测试部分
# test acc: 1.0
# ---------
# Epoch:124,loss0.018060825299471617
# 测试部分
# test acc: 1.0
# ---------
# Epoch:125,loss0.018024582648649812
# 测试部分
# test acc: 1.0
# ---------
# Epoch:126,loss0.017988827312365174
# 测试部分
# test acc: 1.0
# ---------
# Epoch:127,loss0.01795349083840847
# 测试部分
# test acc: 1.0
# ---------
# Epoch:128,loss0.017918606521561742
# 测试部分
# test acc: 1.0
# ---------
# Epoch:129,loss0.0178841648157686
# 测试部分
# test acc: 1.0
# ---------
# Epoch:130,loss0.01785011379979551
# 测试部分
# test acc: 1.0
# ---------
# Epoch:131,loss0.017816497944295406
# 测试部分
# test acc: 1.0
# ---------
# Epoch:132,loss0.01778329908847809
# 测试部分
# test acc: 1.0
# ---------
# Epoch:133,loss0.017750458559021354
# 测试部分
# test acc: 1.0
# ---------
# Epoch:134,loss0.01771804573945701
# 测试部分
# test acc: 1.0
# ---------
# Epoch:135,loss0.01768598728813231
# 测试部分
# test acc: 1.0
# ---------
# Epoch:136,loss0.017654324183240533
# 测试部分
# test acc: 1.0
# ---------
# Epoch:137,loss0.017623017309233546
# 测试部分
# test acc: 1.0
# ---------
# Epoch:138,loss0.01759206922724843
# 测试部分
# test acc: 1.0
# ---------
# Epoch:139,loss0.017561486922204494
# 测试部分
# test acc: 1.0
# ---------
# Epoch:140,loss0.01753123663365841
# 测试部分
# test acc: 1.0
# ---------
# Epoch:141,loss0.01750132767483592
# 测试部分
# test acc: 1.0
# ---------
# Epoch:142,loss0.017471773084253073
# 测试部分
# test acc: 1.0
# ---------
# Epoch:143,loss0.017442532116547227
# 测试部分
# test acc: 1.0
# ---------
# Epoch:144,loss0.017413603840395808
# 测试部分
# test acc: 1.0
# ---------
# Epoch:145,loss0.01738501782529056
# 测试部分
# test acc: 1.0
# ---------
# Epoch:146,loss0.01735673495568335
# 测试部分
# test acc: 1.0
# ---------
# Epoch:147,loss0.01732874009758234
# 测试部分
# test acc: 1.0
# ---------
# Epoch:148,loss0.017301083775237203
# 测试部分
# test acc: 1.0
# ---------
# Epoch:149,loss0.01727369101718068
# 测试部分
# test acc: 1.0
# ---------
# Epoch:150,loss0.01724658557213843
# 测试部分
# test acc: 1.0
# ---------
# Epoch:151,loss0.017219797242432833
# 测试部分
# test acc: 1.0
# ---------
# Epoch:152,loss0.017193264327943325
# 测试部分
# test acc: 1.0
# ---------
# Epoch:153,loss0.017167016165331006
# 测试部分
# test acc: 1.0
# ---------
# Epoch:154,loss0.01714104856364429
# 测试部分
# test acc: 1.0
# ---------
# Epoch:155,loss0.017115335213020444
# 测试部分
# test acc: 1.0
# ---------
# Epoch:156,loss0.01708989217877388
# 测试部分
# test acc: 1.0
# ---------
# Epoch:157,loss0.01706470688804984
# 测试部分
# test acc: 1.0
# ---------
# Epoch:158,loss0.017039780505001545
# 测试部分
# test acc: 1.0
# ---------
# Epoch:159,loss0.017015096498653293
# 测试部分
# test acc: 1.0
# ---------
# Epoch:160,loss0.016990668140351772
# 测试部分
# test acc: 1.0
# ---------
# Epoch:161,loss0.01696647983044386
# 测试部分
# test acc: 1.0
# ---------
# Epoch:162,loss0.016942527145147324
# 测试部分
# test acc: 1.0
# ---------
# Epoch:163,loss0.01691881287842989
# 测试部分
# test acc: 1.0
# ---------
# Epoch:164,loss0.016895329114049673
# 测试部分
# test acc: 1.0
# ---------
# Epoch:165,loss0.016872075852006674
# 测试部分
# test acc: 1.0
# ---------
# Epoch:166,loss0.01684904331341386
# 测试部分
# test acc: 1.0
# ---------
# Epoch:167,loss0.016826246632263064
# 测试部分
# test acc: 1.0
# ---------
# Epoch:168,loss0.016803656239062548
# 测试部分
# test acc: 1.0
# ---------
# Epoch:169,loss0.01678128121420741
# 测试部分
# test acc: 1.0
# ---------
# Epoch:170,loss0.016759122721850872
# 测试部分
# test acc: 1.0
# ---------
# Epoch:171,loss0.016737161902710795
# 测试部分
# test acc: 1.0
# ---------
# Epoch:172,loss0.01671542041003704
# 测试部分
# test acc: 1.0
# ---------
# Epoch:173,loss0.016693870769813657
# 测试部分
# test acc: 1.0
# ---------
# Epoch:174,loss0.016672536032274365
# 测试部分
# test acc: 1.0
# ---------
# Epoch:175,loss0.016651404788717628
# 测试部分
# test acc: 1.0
# ---------
# Epoch:176,loss0.016630435828119516
# 测试部分
# test acc: 1.0
# ---------
# Epoch:177,loss0.01660967990756035
# 测试部分
# test acc: 1.0
# ---------
# Epoch:178,loss0.01658910745754838
# 测试部分
# test acc: 1.0
# ---------
# Epoch:179,loss0.01656872034072876
# 测试部分
# test acc: 1.0
# ---------
# Epoch:180,loss0.016548524843528867
# 测试部分
# test acc: 1.0
# ---------
# Epoch:181,loss0.016528500244021416
# 测试部分
# test acc: 1.0
# ---------
# Epoch:182,loss0.01650867285206914
# 测试部分
# test acc: 1.0
# ---------
# Epoch:183,loss0.01648899936117232
# 测试部分
# test acc: 1.0
# ---------
# Epoch:184,loss0.016469511203467846
# 测试部分
# test acc: 1.0
# ---------
# Epoch:185,loss0.01645019114948809
# 测试部分
# test acc: 1.0
# ---------
# Epoch:186,loss0.016431048745289445
# 测试部分
# test acc: 1.0
# ---------
# Epoch:187,loss0.016412061406299472
# 测试部分
# test acc: 1.0
# ---------
# Epoch:188,loss0.01639324170537293
# 测试部分
# test acc: 1.0
# ---------
# Epoch:189,loss0.016374601516872644
# 测试部分
# test acc: 1.0
# ---------
# Epoch:190,loss0.016356092877686024
# 测试部分
# test acc: 1.0
# ---------
# Epoch:191,loss0.016337770270183682
# 测试部分
# test acc: 1.0
# ---------
# Epoch:192,loss0.0163195903878659
# 测试部分
# test acc: 1.0
# ---------
# Epoch:193,loss0.016301556956022978
# 测试部分
# test acc: 1.0
# ---------
# Epoch:194,loss0.016283699311316013
# 测试部分
# test acc: 1.0
# ---------
# Epoch:195,loss0.016265966929495335
# 测试部分
# test acc: 1.0
# ---------
# Epoch:196,loss0.0162483979947865
# 测试部分
# test acc: 1.0
# ---------
# Epoch:197,loss0.01623098086565733
# 测试部分
# test acc: 1.0
# ---------
# Epoch:198,loss0.01621368434280157
# 测试部分
# test acc: 1.0
# ---------
# Epoch:199,loss0.01619656104594469
# 测试部分
# test acc: 1.0
# ---------
# Epoch:200,loss0.016179556725546718
# 测试部分
# test acc: 1.0
# ---------
# Epoch:201,loss0.016162703512236476
# 测试部分
# test acc: 1.0
# ---------
# Epoch:202,loss0.016145988134667277
# 测试部分
# test acc: 1.0
# ---------
# Epoch:203,loss0.016129403607919812
# 测试部分
# test acc: 1.0
# ---------
# Epoch:204,loss0.016112956684082747
# 测试部分
# test acc: 1.0
# ---------
# Epoch:205,loss0.016096646199002862
# 测试部分
# test acc: 1.0
# ---------
# Epoch:206,loss0.016080460976809263
# 测试部分
# test acc: 1.0
# ---------
# Epoch:207,loss0.016064407536759973
# 测试部分
# test acc: 1.0
# ---------
# Epoch:208,loss0.016048484481871128
# 测试部分
# test acc: 1.0
# ---------
# Epoch:209,loss0.016032679239287972
# 测试部分
# test acc: 1.0
# ---------
# Epoch:210,loss0.016017013229429722
# 测试部分
# test acc: 1.0
# ---------
# Epoch:211,loss0.016001457814127207
# 测试部分
# test acc: 1.0
# ---------
# Epoch:212,loss0.015986030688509345
# 测试部分
# test acc: 1.0
# ---------
# Epoch:213,loss0.015970737673342228
# 测试部分
# test acc: 1.0
# ---------
# Epoch:214,loss0.015955530107021332
# 测试部分
# test acc: 1.0
# ---------
# Epoch:215,loss0.015940470853820443
# 测试部分
# test acc: 1.0
# ---------
# Epoch:216,loss0.015925521729514003
# 测试部分
# test acc: 1.0
# ---------
# Epoch:217,loss0.015910674817860126
# 测试部分
# test acc: 1.0
# ---------
# Epoch:218,loss0.015895960154011846
# 测试部分
# test acc: 1.0
# ---------
# Epoch:219,loss0.01588133769109845
# 测试部分
# test acc: 1.0
# ---------
# Epoch:220,loss0.015866847708821297
# 测试部分
# test acc: 1.0
# ---------
# Epoch:221,loss0.015852457843720913
# 测试部分
# test acc: 1.0
# ---------
# Epoch:222,loss0.01583817577920854
# 测试部分
# test acc: 1.0
# ---------
# Epoch:223,loss0.01582400780171156
# 测试部分
# test acc: 1.0
# ---------
# Epoch:224,loss0.015809929696843028
# 测试部分
# test acc: 1.0
# ---------
# Epoch:225,loss0.015795978717505932
# 测试部分
# test acc: 1.0
# ---------
# Epoch:226,loss0.01578212040476501
# 测试部分
# test acc: 1.0
# ---------
# Epoch:227,loss0.015768363839015365
# 测试部分
# test acc: 1.0
# ---------
# Epoch:228,loss0.015754722524434328
# 测试部分
# test acc: 1.0
# ---------
# Epoch:229,loss0.015741158509626985
# 测试部分
# test acc: 1.0
# ---------
# Epoch:230,loss0.015727709978818893
# 测试部分
# test acc: 1.0
# ---------
# Epoch:231,loss0.01571436133235693
# 测试部分
# test acc: 1.0
# ---------
# Epoch:232,loss0.015701100463047624
# 测试部分
# test acc: 1.0
# ---------
# Epoch:233,loss0.0156879466958344
# 测试部分
# test acc: 1.0
# ---------
# Epoch:234,loss0.015674876514822245
# 测试部分
# test acc: 1.0
# ---------
# Epoch:235,loss0.01566191460005939
# 测试部分
# test acc: 1.0
# ---------
# Epoch:236,loss0.015649035573005676
# 测试部分
# test acc: 1.0
# ---------
# Epoch:237,loss0.015636248979717493
# 测试部分
# test acc: 1.0
# ---------
# Epoch:238,loss0.015623555053025484
# 测试部分
# test acc: 1.0
# ---------
# Epoch:239,loss0.015610962640494108
# 测试部分
# test acc: 1.0
# ---------
# Epoch:240,loss0.015598438447341323
# 测试部分
# test acc: 1.0
# ---------
# Epoch:241,loss0.01558601763099432
# 测试部分
# test acc: 1.0
# ---------
# Epoch:242,loss0.015573689015582204
# 测试部分
# test acc: 1.0
# ---------
# Epoch:243,loss0.01556142303161323
# 测试部分
# test acc: 1.0
# ---------
# Epoch:244,loss0.015549274859949946
# 测试部分
# test acc: 1.0
# ---------
# Epoch:245,loss0.01553719921503216
# 测试部分
# test acc: 1.0
# ---------
# Epoch:246,loss0.015525190392509103
# 测试部分
# test acc: 1.0
# ---------
# Epoch:247,loss0.015513295191340148
# 测试部分
# test acc: 1.0
# ---------
# Epoch:248,loss0.015501460409723222
# 测试部分
# test acc: 1.0
# ---------
# Epoch:249,loss0.015489712823182344
# 测试部分
# test acc: 1.0
# ---------
# Epoch:250,loss0.01547804637812078
# 测试部分
# test acc: 1.0
# ---------
# Epoch:251,loss0.015466455952264369
# 测试部分
# test acc: 1.0
# ---------
# Epoch:252,loss0.01545494666788727
# 测试部分
# test acc: 1.0
# ---------
# Epoch:253,loss0.015443526324816048
# 测试部分
# test acc: 1.0
# ---------
# Epoch:254,loss0.015432174550369382
# 测试部分
# test acc: 1.0
# ---------
# Epoch:255,loss0.015420897048898041
# 测试部分
# test acc: 1.0
# ---------
# Epoch:256,loss0.015409702202305198
# 测试部分
# test acc: 1.0
# ---------
# Epoch:257,loss0.015398564864881337
# 测试部分
# test acc: 1.0
# ---------
# Epoch:258,loss0.015387521940283477
# 测试部分
# test acc: 1.0
# ---------
# Epoch:259,loss0.015376550145447254
# 测试部分
# test acc: 1.0
# ---------
# Epoch:260,loss0.01536564074922353
# 测试部分
# test acc: 1.0
# ---------
# Epoch:261,loss0.015354805742390454
# 测试部分
# test acc: 1.0
# ---------
# Epoch:262,loss0.015344054787419736
# 测试部分
# test acc: 1.0
# ---------
# Epoch:263,loss0.015333368093706667
# 测试部分
# test acc: 1.0
# ---------
# Epoch:264,loss0.015322739374823868
# 测试部分
# test acc: 1.0
# ---------
# Epoch:265,loss0.015312209376133978
# 测试部分
# test acc: 1.0
# ---------
# Epoch:266,loss0.015301715466193855
# 测试部分
# test acc: 1.0
# ---------
# Epoch:267,loss0.01529130304697901
# 测试部分
# test acc: 1.0
# ---------
# Epoch:268,loss0.015280971536412835
# 测试部分
# test acc: 1.0
# ---------
# Epoch:269,loss0.015270684263668954
# 测试部分
# test acc: 1.0
# ---------
# Epoch:270,loss0.015260477201081812
# 测试部分
# test acc: 1.0
# ---------
# Epoch:271,loss0.015250333934091032
# 测试部分
# test acc: 1.0
# ---------
# Epoch:272,loss0.015240264474414289
# 测试部分
# test acc: 1.0
# ---------
# Epoch:273,loss0.015230227611027658
# 测试部分
# test acc: 1.0
# ---------
# Epoch:274,loss0.015220290166325867
# 测试部分
# test acc: 1.0
# ---------
# Epoch:275,loss0.015210395096801221
# 测试部分
# test acc: 1.0
# ---------
# Epoch:276,loss0.015200563124381006
# 测试部分
# test acc: 1.0
# ---------
# Epoch:277,loss0.015190812177024782
# 测试部分
# test acc: 1.0
# ---------
# Epoch:278,loss0.015181106980890036
# 测试部分
# test acc: 1.0
# ---------
# Epoch:279,loss0.015171458944678307
# 测试部分
# test acc: 1.0
# ---------
# Epoch:280,loss0.01516188238747418
# 测试部分
# test acc: 1.0
# ---------
# Epoch:281,loss0.015152363339439034
# 测试部分
# test acc: 1.0
# ---------
# Epoch:282,loss0.015142893185839057
# 测试部分
# test acc: 1.0
# ---------
# Epoch:283,loss0.015133499749936163
# 测试部分
# test acc: 1.0
# ---------
# Epoch:284,loss0.015124144847504795
# 测试部分
# test acc: 1.0
# ---------
# Epoch:285,loss0.01511485071387142
# 测试部分
# test acc: 1.0
# ---------
# Epoch:286,loss0.015105649014003575
# 测试部分
# test acc: 1.0
# ---------
# Epoch:287,loss0.01509645115584135
# 测试部分
# test acc: 1.0
# ---------
# Epoch:288,loss0.015087344567291439
# 测试部分
# test acc: 1.0
# ---------
# Epoch:289,loss0.01507828023750335
# 测试部分
# test acc: 1.0
# ---------
# Epoch:290,loss0.015069269924424589
# 测试部分
# test acc: 1.0
# ---------
# Epoch:291,loss0.015060317236930132
# 测试部分
# test acc: 1.0
# ---------
# Epoch:292,loss0.015051418798975646
# 测试部分
# test acc: 1.0
# ---------
# Epoch:293,loss0.015042576589621603
# 测试部分
# test acc: 1.0
# ---------
# Epoch:294,loss0.015033785603009164
# 测试部分
# test acc: 1.0
# ---------
# Epoch:295,loss0.015025043627247214
# 测试部分
# test acc: 1.0
# ---------
# Epoch:296,loss0.01501635240856558
# 测试部分
# test acc: 1.0
# ---------
# Epoch:297,loss0.01500773336738348
# 测试部分
# test acc: 1.0
# ---------
# Epoch:298,loss0.014999138074927032
# 测试部分
# test acc: 1.0
# ---------
# Epoch:299,loss0.014990606694482267
# 测试部分
# test acc: 1.0
# ---------
# Epoch:300,loss0.014982131193391979
# 测试部分
# test acc: 1.0
# ---------
# Epoch:301,loss0.014973694807849824
# 测试部分
# test acc: 1.0
# ---------
# Epoch:302,loss0.014965313719585538
# 测试部分
# test acc: 1.0
# ---------
# Epoch:303,loss0.014956979546695948
# 测试部分
# test acc: 1.0
# ---------
# Epoch:304,loss0.014948692522011697
# 测试部分
# test acc: 1.0
# ---------
# Epoch:305,loss0.014940451714210212
# 测试部分
# test acc: 1.0
# ---------
# Epoch:306,loss0.014932271442376077
# 测试部分
# test acc: 1.0
# ---------
# Epoch:307,loss0.014924131100997329
# 测试部分
# test acc: 1.0
# ---------
# Epoch:308,loss0.01491604174952954
# 测试部分
# test acc: 1.0
# ---------
# Epoch:309,loss0.014907981851138175
# 测试部分
# test acc: 1.0
# ---------
# Epoch:310,loss0.014899994130246341
# 测试部分
# test acc: 1.0
# ---------
# Epoch:311,loss0.014892029343172908
# 测试部分
# test acc: 1.0
# ---------
# Epoch:312,loss0.01488412159960717
# 测试部分
# test acc: 1.0
# ---------
# Epoch:313,loss0.014876257511787117
# 测试部分
# test acc: 1.0
# ---------
# Epoch:314,loss0.014868434402160347
# 测试部分
# test acc: 1.0
# ---------
# Epoch:315,loss0.014860664261505008
# 测试部分
# test acc: 1.0
# ---------
# Epoch:316,loss0.01485293300356716
# 测试部分
# test acc: 1.0
# ---------
# Epoch:317,loss0.014845237950794399
# 测试部分
# test acc: 1.0
# ---------
# Epoch:318,loss0.014837599825114012
# 测试部分
# test acc: 1.0
# ---------
# Epoch:319,loss0.014829996740445495
# 测试部分
# test acc: 1.0
# ---------
# Epoch:320,loss0.01482243521604687
# 测试部分
# test acc: 1.0
# ---------
# Epoch:321,loss0.014814923633821309
# 测试部分
# test acc: 1.0
# ---------
# Epoch:322,loss0.014807445695623755
# 测试部分
# test acc: 1.0
# ---------
# Epoch:323,loss0.014800010365433991
# 测试部分
# test acc: 1.0
# ---------
# Epoch:324,loss0.014792613917961717
# 测试部分
# test acc: 1.0
# ---------
# Epoch:325,loss0.014785272884182632
# 测试部分
# test acc: 1.0
# ---------
# Epoch:326,loss0.014777956530451775
# 测试部分
# test acc: 1.0
# ---------
# Epoch:327,loss0.014770680107176304
# 测试部分
# test acc: 1.0
# ---------
# Epoch:328,loss0.014763458399102092
# 测试部分
# test acc: 1.0
# ---------
# Epoch:329,loss0.014756269636563957
# 测试部分
# test acc: 1.0
# ---------
# Epoch:330,loss0.0147491100942716
# 测试部分
# test acc: 1.0
# ---------
# Epoch:331,loss0.014742006896995008
# 测试部分
# test acc: 1.0
# ---------
# Epoch:332,loss0.014734933385625482
# 测试部分
# test acc: 1.0
# ---------
# Epoch:333,loss0.014727887813933194
# 测试部分
# test acc: 1.0
# ---------
# Epoch:334,loss0.014720903942361474
# 测试部分
# test acc: 1.0
# ---------
# Epoch:335,loss0.014713941724039614
# 测试部分
# test acc: 1.0
# ---------
# Epoch:336,loss0.01470699580386281
# 测试部分
# test acc: 1.0
# ---------
# Epoch:337,loss0.014700142433866858
# 测试部分
# test acc: 1.0
# ---------
# Epoch:338,loss0.014693279401399195
# 测试部分
# test acc: 1.0
# ---------
# Epoch:339,loss0.014686463284306228
# 测试部分
# test acc: 1.0
# ---------
# Epoch:340,loss0.014679685118608177
# 测试部分
# test acc: 1.0
# ---------
# Epoch:341,loss0.014672953402623534
# 测试部分
# test acc: 1.0
# ---------
# Epoch:342,loss0.014666244969703257
# 测试部分
# test acc: 1.0
# ---------
# Epoch:343,loss0.014659570879302919
# 测试部分
# test acc: 1.0
# ---------
# Epoch:344,loss0.014652951271273196
# 测试部分
# test acc: 1.0
# ---------
# Epoch:345,loss0.01464633469004184
# 测试部分
# test acc: 1.0
# ---------
# Epoch:346,loss0.014639781438745558
# 测试部分
# test acc: 1.0
# ---------
# Epoch:347,loss0.014633247861638665
# 测试部分
# test acc: 1.0
# ---------
# Epoch:348,loss0.014626748627051711
# 测试部分
# test acc: 1.0
# ---------
# Epoch:349,loss0.014620288624428213
# 测试部分
# test acc: 1.0
# ---------
# Epoch:350,loss0.01461386273149401
# 测试部分
# test acc: 1.0
# ---------
# Epoch:351,loss0.014607467572204769
# 测试部分
# test acc: 1.0
# ---------
# Epoch:352,loss0.014601109200157225
# 测试部分
# test acc: 1.0
# ---------
# Epoch:353,loss0.014594775391742587
# 测试部分
# test acc: 1.0
# ---------
# Epoch:354,loss0.014588486403226852
# 测试部分
# test acc: 1.0
# ---------
# Epoch:355,loss0.014582205447368324
# 测试部分
# test acc: 1.0
# ---------
# Epoch:356,loss0.014575987355783582
# 测试部分
# test acc: 1.0
# ---------
# Epoch:357,loss0.014569777180440724
# 测试部分
# test acc: 1.0
# ---------
# Epoch:358,loss0.014563610311597586
# 测试部分
# test acc: 1.0
# ---------
# Epoch:359,loss0.0145574671914801
# 测试部分
# test acc: 1.0
# ---------
# Epoch:360,loss0.014551367261447012
# 测试部分
# test acc: 1.0
# ---------
# Epoch:361,loss0.014545284095220268
# 测试部分
# test acc: 1.0
# ---------
# Epoch:362,loss0.014539248310029507
# 测试部分
# test acc: 1.0
# ---------
# Epoch:363,loss0.014533231500536203
# 测试部分
# test acc: 1.0
# ---------
# Epoch:364,loss0.014527247403748333
# 测试部分
# test acc: 1.0
# ---------
# Epoch:365,loss0.014521289966069162
# 测试部分
# test acc: 1.0
# ---------
# Epoch:366,loss0.014515359071083367
# 测试部分
# test acc: 1.0
# ---------
# Epoch:367,loss0.014509470434859395
# 测试部分
# test acc: 1.0
# ---------
# Epoch:368,loss0.01450359751470387
# 测试部分
# test acc: 1.0
# ---------
# Epoch:369,loss0.01449776126537472
# 测试部分
# test acc: 1.0
# ---------
# Epoch:370,loss0.01449196261819452
# 测试部分
# test acc: 1.0
# ---------
# Epoch:371,loss0.014486179919913411
# 测试部分
# test acc: 1.0
# ---------
# Epoch:372,loss0.014480430050753057
# 测试部分
# test acc: 1.0
# ---------
# Epoch:373,loss0.014474703697487712
# 测试部分
# test acc: 1.0
# ---------
# Epoch:374,loss0.01446901133749634
# 测试部分
# test acc: 1.0
# ---------
# Epoch:375,loss0.014463349594734609
# 测试部分
# test acc: 1.0
# ---------
# Epoch:376,loss0.01445770321879536
# 测试部分
# test acc: 1.0
# ---------
# Epoch:377,loss0.014452091767452657
# 测试部分
# test acc: 1.0
# ---------
# Epoch:378,loss0.014446514542214572
# 测试部分
# test acc: 1.0
# ---------
# Epoch:379,loss0.014440948492847383
# 测试部分
# test acc: 1.0
# ---------
# Epoch:380,loss0.014435417484492064
# 测试部分
# test acc: 1.0
# ---------
# Epoch:381,loss0.014429923496209085
# 测试部分
# test acc: 1.0
# ---------
# Epoch:382,loss0.014424436609260738
# 测试部分
# test acc: 1.0
# ---------
# Epoch:383,loss0.014418995124287903
# 测试部分
# test acc: 1.0
# ---------
# Epoch:384,loss0.014413560158573091
# 测试部分
# test acc: 1.0
# ---------
# Epoch:385,loss0.014408164541237056
# 测试部分
# test acc: 1.0
# ---------
# Epoch:386,loss0.014402791042812169
# 测试部分
# test acc: 1.0
# ---------
# Epoch:387,loss0.01439743919763714
# 测试部分
# test acc: 1.0
# ---------
# Epoch:388,loss0.014392129145562649
# 测试部分
# test acc: 1.0
# ---------
# Epoch:389,loss0.014386819442734122
# 测试部分
# test acc: 1.0
# ---------
# Epoch:390,loss0.014381557703018188
# 测试部分
# test acc: 1.0
# ---------
# Epoch:391,loss0.0143763090018183
# 测试部分
# test acc: 1.0
# ---------
# Epoch:392,loss0.014371079741977155
# 测试部分
# test acc: 1.0
# ---------
# Epoch:393,loss0.014365882729180157
# 测试部分
# test acc: 1.0
# ---------
# Epoch:394,loss0.014360724366270006
# 测试部分
# test acc: 1.0
# ---------
# Epoch:395,loss0.014355559251271188
# 测试部分
# test acc: 1.0
# ---------
# Epoch:396,loss0.014350439189001918
# 测试部分
# test acc: 1.0
# ---------
# Epoch:397,loss0.014345344854518771
# 测试部分
# test acc: 1.0
# ---------
# Epoch:398,loss0.01434026483912021
# 测试部分
# test acc: 1.0
# ---------
# Epoch:399,loss0.014335198211483657
# 测试部分
# test acc: 1.0
# ---------
# Epoch:400,loss0.014330179779790342
# 测试部分
# test acc: 1.0
# ---------
# Epoch:401,loss0.014325177879072726
# 测试部分
# test acc: 1.0
# ---------
# Epoch:402,loss0.014320179470814764
# 测试部分
# test acc: 1.0
# ---------
# Epoch:403,loss0.01431523624341935
# 测试部分
# test acc: 1.0
# ---------
# Epoch:404,loss0.014310296275652945
# 测试部分
# test acc: 1.0
# ---------
# Epoch:405,loss0.014305356540717185
# 测试部分
# test acc: 1.0
# ---------
# Epoch:406,loss0.014300484559498727
# 测试部分
# test acc: 1.0
# ---------
# Epoch:407,loss0.014295612811110914
# 测试部分
# test acc: 1.0
# ---------
# Epoch:408,loss0.014290758990682662
# 测试部分
# test acc: 1.0
# ---------
# Epoch:409,loss0.014285923563875258
# 测试部分
# test acc: 1.0
# ---------
# Epoch:410,loss0.014281123992986977
# 测试部分
# test acc: 1.0
# ---------
# Epoch:411,loss0.014276350964792073
# 测试部分
# test acc: 1.0
# ---------
# Epoch:412,loss0.014271582127548754
# 测试部分
# test acc: 1.0
# ---------
# Epoch:413,loss0.014266838901676238
# 测试部分
# test acc: 1.0
# ---------
# Epoch:414,loss0.01426211791113019
# 测试部分
# test acc: 1.0
# ---------
# Epoch:415,loss0.014257428119890392
# 测试部分
# test acc: 1.0
# ---------
# Epoch:416,loss0.014252756023779511
# 测试部分
# test acc: 1.0
# ---------
# Epoch:417,loss0.014248086954466999
# 测试部分
# test acc: 1.0
# ---------
# Epoch:418,loss0.014243459678255022
# 测试部分
# test acc: 1.0
# ---------
# Epoch:419,loss0.01423885056283325
# 测试部分
# test acc: 1.0
# ---------
# Epoch:420,loss0.014234248432330787
# 测试部分
# test acc: 1.0
# ---------
# Epoch:421,loss0.014229674939997494
# 测试部分
# test acc: 1.0
# ---------
# Epoch:422,loss0.01422511984128505
# 测试部分
# test acc: 1.0
# ---------
# Epoch:423,loss0.014220590004697442
# 测试部分
# test acc: 1.0
# ---------
# Epoch:424,loss0.014216066687367857
# 测试部分
# test acc: 1.0
# ---------
# Epoch:425,loss0.014211585163138807
# 测试部分
# test acc: 1.0
# ---------
# Epoch:426,loss0.01420710829552263
# 测试部分
# test acc: 1.0
# ---------
# Epoch:427,loss0.014202650636434555
# 测试部分
# test acc: 1.0
# ---------
# Epoch:428,loss0.014198216726072133
# 测试部分
# test acc: 1.0
# ---------
# Epoch:429,loss0.014193804701790214
# 测试部分
# test acc: 1.0
# ---------
# Epoch:430,loss0.01418939686845988
# 测试部分
# test acc: 1.0
# ---------
# Epoch:431,loss0.014185020816512406
# 测试部分
# test acc: 1.0
# ---------
# Epoch:432,loss0.014180669910274446
# 测试部分
# test acc: 1.0
# ---------
# Epoch:433,loss0.01417631993535906
# 测试部分
# test acc: 1.0
# ---------
# Epoch:434,loss0.014172004302963614
# 测试部分
# test acc: 1.0
# ---------
# Epoch:435,loss0.014167713117785752
# 测试部分
# test acc: 1.0
# ---------
# Epoch:436,loss0.014163423562422395
# 测试部分
# test acc: 1.0
# ---------
# Epoch:437,loss0.014159139012917876
# 测试部分
# test acc: 1.0
# ---------
# Epoch:438,loss0.014154912671074271
# 测试部分
# test acc: 1.0
# ---------
# Epoch:439,loss0.014150677714496851
# 测试部分
# test acc: 1.0
# ---------
# Epoch:440,loss0.014146466157399118
# 测试部分
# test acc: 1.0
# ---------
# Epoch:441,loss0.014142281608656049
# 测试部分
# test acc: 1.0
# ---------
# Epoch:442,loss0.014138103229925036
# 测试部分
# test acc: 1.0
# ---------
# Epoch:443,loss0.014133928925730288
# 测试部分
# test acc: 1.0
# ---------
# Epoch:444,loss0.014129797695204616
# 测试部分
# test acc: 1.0
# ---------
# Epoch:445,loss0.014125677989795804
# 测试部分
# test acc: 1.0
# ---------
# Epoch:446,loss0.014121563988737762
# 测试部分
# test acc: 1.0
# ---------
# Epoch:447,loss0.014117479673586786
# 测试部分
# test acc: 1.0
# ---------
# Epoch:448,loss0.014113407698459923
# 测试部分
# test acc: 1.0
# ---------
# Epoch:449,loss0.014109352021478117
# 测试部分
# test acc: 1.0
# ---------
# Epoch:450,loss0.014105312759056687
# 测试部分
# test acc: 1.0
# ---------
# Epoch:451,loss0.01410128886345774
# 测试部分
# test acc: 1.0
# ---------
# Epoch:452,loss0.014097290462814271
# 测试部分
# test acc: 1.0
# ---------
# Epoch:453,loss0.014093308127485216
# 测试部分
# test acc: 1.0
# ---------
# Epoch:454,loss0.014089317643083632
# 测试部分
# test acc: 1.0
# ---------
# Epoch:455,loss0.014085388625971973
# 测试部分
# test acc: 1.0
# ---------
# Epoch:456,loss0.01408143702428788
# 测试部分
# test acc: 1.0
# ---------
# Epoch:457,loss0.014077513595111668
# 测试部分
# test acc: 1.0
# ---------
# Epoch:458,loss0.014073620433919132
# 测试部分
# test acc: 1.0
# ---------
# Epoch:459,loss0.014069717843085527
# 测试部分
# test acc: 1.0
# ---------
# Epoch:460,loss0.014065848314203322
# 测试部分
# test acc: 1.0
# ---------
# Epoch:461,loss0.014061982743442059
# 测试部分
# test acc: 1.0
# ---------
# Epoch:462,loss0.014058151515200734
# 测试部分
# test acc: 1.0
# ---------
# Epoch:463,loss0.014054323663003743
# 测试部分
# test acc: 1.0
# ---------
# Epoch:464,loss0.014050516998395324
# 测试部分
# test acc: 1.0
# ---------
# Epoch:465,loss0.01404671196360141
# 测试部分
# test acc: 1.0
# ---------
# Epoch:466,loss0.014042934984900057
# 测试部分
# test acc: 1.0
# ---------
# Epoch:467,loss0.014039175701327622
# 测试部分
# test acc: 1.0
# ---------
# Epoch:468,loss0.01403541408944875
# 测试部分
# test acc: 1.0
# ---------
# Epoch:469,loss0.014031683676876128
# 测试部分
# test acc: 1.0
# ---------
# Epoch:470,loss0.014027963043190539
# 测试部分
# test acc: 1.0
# ---------
# Epoch:471,loss0.014024264295585454
# 测试部分
# test acc: 1.0
# ---------
# Epoch:472,loss0.01402056182269007
# 测试部分
# test acc: 1.0
# ---------
# Epoch:473,loss0.01401689334306866
# 测试部分
# test acc: 1.0
# ---------
# Epoch:474,loss0.014013235457241535
# 测试部分
# test acc: 1.0
# ---------
# Epoch:475,loss0.014009579899720848
# 测试部分
# test acc: 1.0
# ---------
# Epoch:476,loss0.014005955075845122
# 测试部分
# test acc: 1.0
# ---------
# Epoch:477,loss0.014002340962179005
# 测试部分
# test acc: 1.0
# ---------
# Epoch:478,loss0.013998735812492669
# 测试部分
# test acc: 1.0
# ---------
# Epoch:479,loss0.013995141140185297
# 测试部分
# test acc: 1.0
# ---------
# Epoch:480,loss0.013991574640385807
# 测试部分
# test acc: 1.0
# ---------
# Epoch:481,loss0.013988003483973444
# 测试部分
# test acc: 1.0
# ---------
# Epoch:482,loss0.013984457938931882
# 测试部分
# test acc: 1.0
# ---------
# Epoch:483,loss0.013980936608277261
# 测试部分
# test acc: 1.0
# ---------
# Epoch:484,loss0.013977404916658998
# 测试部分
# test acc: 1.0
# ---------
# Epoch:485,loss0.01397391117643565
# 测试部分
# test acc: 1.0
# ---------
# Epoch:486,loss0.013970413361676037
# 测试部分
# test acc: 1.0
# ---------
# Epoch:487,loss0.01396693557035178
# 测试部分
# test acc: 1.0
# ---------
# Epoch:488,loss0.013963473029434681
# 测试部分
# test acc: 1.0
# ---------
# Epoch:489,loss0.013960016192868352
# 测试部分
# test acc: 1.0
# ---------
# Epoch:490,loss0.013956574373878539
# 测试部分
# test acc: 1.0
# ---------
# Epoch:491,loss0.013953150599263608
# 测试部分
# test acc: 1.0
# ---------
# Epoch:492,loss0.013949743937700987
# 测试部分
# test acc: 1.0
# ---------
# Epoch:493,loss0.013946344261057675
# 测试部分
# test acc: 1.0
# ---------
# Epoch:494,loss0.013942962163127959
# 测试部分
# test acc: 1.0
# ---------
# Epoch:495,loss0.013939584256149828
# 测试部分
# test acc: 1.0
# ---------
# Epoch:496,loss0.013936232659034431
# 测试部分
# test acc: 1.0
# ---------
# Epoch:497,loss0.013932874542661011
# 测试部分
# test acc: 1.0
# ---------
# Epoch:498,loss0.013929549255408347
# 测试部分
# test acc: 1.0
# ---------
# Epoch:499,loss0.013926226296462119
# 测试部分
# test acc: 1.0
# ---------
# total_time: 7.54794716835022
